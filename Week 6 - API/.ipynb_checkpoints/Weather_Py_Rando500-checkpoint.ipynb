# %%
## WeatherPy

In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.

Your objective is to build a series of scatter plots to showcase the following relationships:

* Temperature (F) vs. Latitude
* Humidity (%) vs. Latitude
* Cloudiness (%) vs. Latitude
* Wind Speed (mph) vs. Latitude

Your final notebook must:

* Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
* Perform a weather check on each of the cities using a series of successive API calls. 
* Include a print log of each city as it's being processed with the city number, city name, and requested URL.
* Save both a CSV of all data retrieved and png images for each scatter plot.

# %%
from citipy import citipy
import requests as req
import matplotlib.pyplot as plt
import pandas as pd
import csv
import random

# %%
weather_data =[]
req_url =[]

for i in range (0, 600):
    
    num = random.random()
    lat_int = random.randint(0,180)-90
    long_int =random.randint(0,360)-180
    lat = num*lat_int
    long = num*long_int
    
    #insert geocodes
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code

    # Build partial query URL
    url = "http://api.openweathermap.org/data/2.5/weather?"
    # api.openweathermap.org/data/2.5/weather?q={city name},{country code}
    # api.openweathermap.org/data/2.5/weather?q=London,uk
    api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"
    units = "imperial"
    
    query_url = url + "appid=" + api_key + "&units=" + units + "&q="+'%s,%s' % (city_name, country_code)
    response = req.get(query_url).json()
    if response.get ('cod') != '404':
        weather_data.append(response)
        req_url.append(query_url)

# %%
# Extract interesting data from responses
city_data = [data.get("name") for data in weather_data]
city_code = [data.get('cod') for data in weather_data]
lat_data = [data.get("coord").get("lat") for data in weather_data]
temp_data = [data.get("main").get("temp") for data in weather_data]
humidity_data = [data.get("main").get("humidity") for data in weather_data]
cloudiness_data = [data.get("clouds").get("all") for data in weather_data]
windspeed_data = [data.get("wind").get("speed") for data in weather_data]

# %%
#citycount = len(city_data)
#citycount
#print(req_url[i])
for i in range (0,500):
    citynum = i+1
    print ('Processing city %s out of 500 | %s' %(citynum, city_data[i]))
    print (req_url[i])
    print('---------------------------------------------------------------------------------------------')
# Out:
# Processing city 1 out of 500 | Mopipi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mopipi,bw
# ---------------------------------------------------------------------------------------------
# Processing city 2 out of 500 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cayenne,gf
# ---------------------------------------------------------------------------------------------
# Processing city 3 out of 500 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cidreira,br
# ---------------------------------------------------------------------------------------------
# Processing city 4 out of 500 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ushuaia,ar
# ---------------------------------------------------------------------------------------------
# Processing city 5 out of 500 | Amapa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=amapa,br
# ---------------------------------------------------------------------------------------------
# Processing city 6 out of 500 | Mumford
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mumford,gh
# ---------------------------------------------------------------------------------------------
# Processing city 7 out of 500 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=arraial do cabo,br
# ---------------------------------------------------------------------------------------------
# Processing city 8 out of 500 | Torbay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=torbay,ca
# ---------------------------------------------------------------------------------------------
# Processing city 9 out of 500 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=new norfolk,au
# ---------------------------------------------------------------------------------------------
# Processing city 10 out of 500 | Touros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=touros,br
# ---------------------------------------------------------------------------------------------
# Processing city 11 out of 500 | Albany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=albany,au
# ---------------------------------------------------------------------------------------------
# Processing city 12 out of 500 | Chilca
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=chilca,pe
# ---------------------------------------------------------------------------------------------
# Processing city 13 out of 500 | Kilindoni
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kilindoni,tz
# ---------------------------------------------------------------------------------------------
# Processing city 14 out of 500 | Cocobeach
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cocobeach,ga
# ---------------------------------------------------------------------------------------------
# Processing city 15 out of 500 | Kassala
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kassala,sd
# ---------------------------------------------------------------------------------------------
# Processing city 16 out of 500 | San-Pedro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=san-pedro,ci
# ---------------------------------------------------------------------------------------------
# Processing city 17 out of 500 | Maceio
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=maceio,br
# ---------------------------------------------------------------------------------------------
# Processing city 18 out of 500 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port-gentil,ga
# ---------------------------------------------------------------------------------------------
# Processing city 19 out of 500 | Fomboni
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=fomboni,km
# ---------------------------------------------------------------------------------------------
# Processing city 20 out of 500 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=coquimbo,cl
# ---------------------------------------------------------------------------------------------
# Processing city 21 out of 500 | Itarema
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=itarema,br
# ---------------------------------------------------------------------------------------------
# Processing city 22 out of 500 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=monrovia,lr
# ---------------------------------------------------------------------------------------------
# Processing city 23 out of 500 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=san cristobal,ec
# ---------------------------------------------------------------------------------------------
# Processing city 24 out of 500 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ribeira grande,pt
# ---------------------------------------------------------------------------------------------
# Processing city 25 out of 500 | Namibe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=namibe,ao
# ---------------------------------------------------------------------------------------------
# Processing city 26 out of 500 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=lagoa,pt
# ---------------------------------------------------------------------------------------------
# Processing city 27 out of 500 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=grindavik,is
# ---------------------------------------------------------------------------------------------
# Processing city 28 out of 500 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=lebu,cl
# ---------------------------------------------------------------------------------------------
# Processing city 29 out of 500 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hilo,us
# ---------------------------------------------------------------------------------------------
# Processing city 30 out of 500 | Kangaba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kangaba,ml
# ---------------------------------------------------------------------------------------------
# Processing city 31 out of 500 | Evinayong
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=evinayong,gq
# ---------------------------------------------------------------------------------------------
# Processing city 32 out of 500 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kodiak,us
# ---------------------------------------------------------------------------------------------
# Processing city 33 out of 500 | Ayna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ayna,pe
# ---------------------------------------------------------------------------------------------
# Processing city 34 out of 500 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=arraial do cabo,br
# ---------------------------------------------------------------------------------------------
# Processing city 35 out of 500 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=saldanha,za
# ---------------------------------------------------------------------------------------------
# Processing city 36 out of 500 | Masingbi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=masingbi,sl
# ---------------------------------------------------------------------------------------------
# Processing city 37 out of 500 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=luderitz,na
# ---------------------------------------------------------------------------------------------
# Processing city 38 out of 500 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ushuaia,ar
# ---------------------------------------------------------------------------------------------
# Processing city 39 out of 500 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ponta do sol,cv
# ---------------------------------------------------------------------------------------------
# Processing city 40 out of 500 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hilo,us
# ---------------------------------------------------------------------------------------------
# Processing city 41 out of 500 | Taltal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=taltal,cl
# ---------------------------------------------------------------------------------------------
# Processing city 42 out of 500 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=maragogi,br
# ---------------------------------------------------------------------------------------------
# Processing city 43 out of 500 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=narsaq,gl
# ---------------------------------------------------------------------------------------------
# Processing city 44 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 45 out of 500 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cabo san lucas,mx
# ---------------------------------------------------------------------------------------------
# Processing city 46 out of 500 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=new norfolk,au
# ---------------------------------------------------------------------------------------------
# Processing city 47 out of 500 | Kuito
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kuito,ao
# ---------------------------------------------------------------------------------------------
# Processing city 48 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 49 out of 500 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=harper,lr
# ---------------------------------------------------------------------------------------------
# Processing city 50 out of 500 | Albany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=albany,au
# ---------------------------------------------------------------------------------------------
# Processing city 51 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 52 out of 500 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rikitea,pf
# ---------------------------------------------------------------------------------------------
# Processing city 53 out of 500 | Khartoum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=khartoum,sd
# ---------------------------------------------------------------------------------------------
# Processing city 54 out of 500 | Amapa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=amapa,br
# ---------------------------------------------------------------------------------------------
# Processing city 55 out of 500 | Siena
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=siena,it
# ---------------------------------------------------------------------------------------------
# Processing city 56 out of 500 | Owo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=owo,ng
# ---------------------------------------------------------------------------------------------
# Processing city 57 out of 500 | Banikoara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=banikoara,bj
# ---------------------------------------------------------------------------------------------
# Processing city 58 out of 500 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port hedland,au
# ---------------------------------------------------------------------------------------------
# Processing city 59 out of 500 | Vuktyl
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=vuktyl,ru
# ---------------------------------------------------------------------------------------------
# Processing city 60 out of 500 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rikitea,pf
# ---------------------------------------------------------------------------------------------
# Processing city 61 out of 500 | Diffa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=diffa,ne
# ---------------------------------------------------------------------------------------------
# Processing city 62 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 63 out of 500 | Maraa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=maraa,br
# ---------------------------------------------------------------------------------------------
# Processing city 64 out of 500 | Coihueco
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=coihueco,cl
# ---------------------------------------------------------------------------------------------
# Processing city 65 out of 500 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=carnarvon,au
# ---------------------------------------------------------------------------------------------
# Processing city 66 out of 500 | Road Town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=road town,vg
# ---------------------------------------------------------------------------------------------
# Processing city 67 out of 500 | Victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=victoria,sc
# ---------------------------------------------------------------------------------------------
# Processing city 68 out of 500 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=constitucion,mx
# ---------------------------------------------------------------------------------------------
# Processing city 69 out of 500 | Seoul
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=seoul,kr
# ---------------------------------------------------------------------------------------------
# Processing city 70 out of 500 | Lamar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=lamar,us
# ---------------------------------------------------------------------------------------------
# Processing city 71 out of 500 | San-Pedro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=san-pedro,ci
# ---------------------------------------------------------------------------------------------
# Processing city 72 out of 500 | Touros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=touros,br
# ---------------------------------------------------------------------------------------------
# Processing city 73 out of 500 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=lebu,cl
# ---------------------------------------------------------------------------------------------
# Processing city 74 out of 500 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ribeira grande,pt
# ---------------------------------------------------------------------------------------------
# Processing city 75 out of 500 | Soyo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=soyo,ao
# ---------------------------------------------------------------------------------------------
# Processing city 76 out of 500 | Sao Miguel do Araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao miguel do araguaia,br
# ---------------------------------------------------------------------------------------------
# Processing city 77 out of 500 | Waddan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=waddan,ly
# ---------------------------------------------------------------------------------------------
# Processing city 78 out of 500 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hilo,us
# ---------------------------------------------------------------------------------------------
# Processing city 79 out of 500 | Nokaneng
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=nokaneng,bw
# ---------------------------------------------------------------------------------------------
# Processing city 80 out of 500 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hualmay,pe
# ---------------------------------------------------------------------------------------------
# Processing city 81 out of 500 | Bhadohi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bhadohi,in
# ---------------------------------------------------------------------------------------------
# Processing city 82 out of 500 | Axim
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=axim,gh
# ---------------------------------------------------------------------------------------------
# Processing city 83 out of 500 | Nivala
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=nivala,fi
# ---------------------------------------------------------------------------------------------
# Processing city 84 out of 500 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=half moon bay,us
# ---------------------------------------------------------------------------------------------
# Processing city 85 out of 500 | Atuona
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=atuona,pf
# ---------------------------------------------------------------------------------------------
# Processing city 86 out of 500 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=belmonte,br
# ---------------------------------------------------------------------------------------------
# Processing city 87 out of 500 | Torbay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=torbay,ca
# ---------------------------------------------------------------------------------------------
# Processing city 88 out of 500 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=geraldton,au
# ---------------------------------------------------------------------------------------------
# Processing city 89 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 90 out of 500 | Soubre
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=soubre,ci
# ---------------------------------------------------------------------------------------------
# Processing city 91 out of 500 | Souillac
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=souillac,mu
# ---------------------------------------------------------------------------------------------
# Processing city 92 out of 500 | Bama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bama,ng
# ---------------------------------------------------------------------------------------------
# Processing city 93 out of 500 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bathsheba,bb
# ---------------------------------------------------------------------------------------------
# Processing city 94 out of 500 | Tongren
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tongren,cn
# ---------------------------------------------------------------------------------------------
# Processing city 95 out of 500 | Deori
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=deori,in
# ---------------------------------------------------------------------------------------------
# Processing city 96 out of 500 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mahebourg,mu
# ---------------------------------------------------------------------------------------------
# Processing city 97 out of 500 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hithadhoo,mv
# ---------------------------------------------------------------------------------------------
# Processing city 98 out of 500 | Bergen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bergen,de
# ---------------------------------------------------------------------------------------------
# Processing city 99 out of 500 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port-gentil,ga
# ---------------------------------------------------------------------------------------------
# Processing city 100 out of 500 | Ladario
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ladario,br
# ---------------------------------------------------------------------------------------------
# Processing city 101 out of 500 | Adeje
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=adeje,es
# ---------------------------------------------------------------------------------------------
# Processing city 102 out of 500 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=takoradi,gh
# ---------------------------------------------------------------------------------------------
# Processing city 103 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 104 out of 500 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hambantota,lk
# ---------------------------------------------------------------------------------------------
# Processing city 105 out of 500 | Basoko
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=basoko,cd
# ---------------------------------------------------------------------------------------------
# Processing city 106 out of 500 | Robertsport
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=robertsport,lr
# ---------------------------------------------------------------------------------------------
# Processing city 107 out of 500 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rikitea,pf
# ---------------------------------------------------------------------------------------------
# Processing city 108 out of 500 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hithadhoo,mv
# ---------------------------------------------------------------------------------------------
# Processing city 109 out of 500 | Machali
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=machali,cl
# ---------------------------------------------------------------------------------------------
# Processing city 110 out of 500 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=harper,lr
# ---------------------------------------------------------------------------------------------
# Processing city 111 out of 500 | Les Cayes
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=les cayes,ht
# ---------------------------------------------------------------------------------------------
# Processing city 112 out of 500 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tuktoyaktuk,ca
# ---------------------------------------------------------------------------------------------
# Processing city 113 out of 500 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao filipe,cv
# ---------------------------------------------------------------------------------------------
# Processing city 114 out of 500 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=new norfolk,au
# ---------------------------------------------------------------------------------------------
# Processing city 115 out of 500 | Taltal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=taltal,cl
# ---------------------------------------------------------------------------------------------
# Processing city 116 out of 500 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hamilton,bm
# ---------------------------------------------------------------------------------------------
# Processing city 117 out of 500 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao joao da barra,br
# ---------------------------------------------------------------------------------------------
# Processing city 118 out of 500 | Muros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=muros,es
# ---------------------------------------------------------------------------------------------
# Processing city 119 out of 500 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=takoradi,gh
# ---------------------------------------------------------------------------------------------
# Processing city 120 out of 500 | Bagdarin
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bagdarin,ru
# ---------------------------------------------------------------------------------------------
# Processing city 121 out of 500 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=lebu,cl
# ---------------------------------------------------------------------------------------------
# Processing city 122 out of 500 | Amalapuram
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=amalapuram,in
# ---------------------------------------------------------------------------------------------
# Processing city 123 out of 500 | Bauchi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bauchi,ng
# ---------------------------------------------------------------------------------------------
# Processing city 124 out of 500 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=new norfolk,au
# ---------------------------------------------------------------------------------------------
# Processing city 125 out of 500 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=prince rupert,ca
# ---------------------------------------------------------------------------------------------
# Processing city 126 out of 500 | Mumford
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mumford,gh
# ---------------------------------------------------------------------------------------------
# Processing city 127 out of 500 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=luderitz,na
# ---------------------------------------------------------------------------------------------
# Processing city 128 out of 500 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=carnarvon,au
# ---------------------------------------------------------------------------------------------
# Processing city 129 out of 500 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port lincoln,au
# ---------------------------------------------------------------------------------------------
# Processing city 130 out of 500 | Victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=victoria,sc
# ---------------------------------------------------------------------------------------------
# Processing city 131 out of 500 | Wote
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=wote,ke
# ---------------------------------------------------------------------------------------------
# Processing city 132 out of 500 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=quelimane,mz
# ---------------------------------------------------------------------------------------------
# Processing city 133 out of 500 | Victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=victoria,sc
# ---------------------------------------------------------------------------------------------
# Processing city 134 out of 500 | Saint George
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=saint george,bm
# ---------------------------------------------------------------------------------------------
# Processing city 135 out of 500 | Omboue
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=omboue,ga
# ---------------------------------------------------------------------------------------------
# Processing city 136 out of 500 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bandarbeyla,so
# ---------------------------------------------------------------------------------------------
# Processing city 137 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 138 out of 500 | Kibondo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kibondo,tz
# ---------------------------------------------------------------------------------------------
# Processing city 139 out of 500 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hithadhoo,mv
# ---------------------------------------------------------------------------------------------
# Processing city 140 out of 500 | Trairi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=trairi,br
# ---------------------------------------------------------------------------------------------
# Processing city 141 out of 500 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tiksi,ru
# ---------------------------------------------------------------------------------------------
# Processing city 142 out of 500 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mahebourg,mu
# ---------------------------------------------------------------------------------------------
# Processing city 143 out of 500 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mandalgovi,mn
# ---------------------------------------------------------------------------------------------
# Processing city 144 out of 500 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hobyo,so
# ---------------------------------------------------------------------------------------------
# Processing city 145 out of 500 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tessalit,ml
# ---------------------------------------------------------------------------------------------
# Processing city 146 out of 500 | Grand-Lahou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=grand-lahou,ci
# ---------------------------------------------------------------------------------------------
# Processing city 147 out of 500 | Kutum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kutum,sd
# ---------------------------------------------------------------------------------------------
# Processing city 148 out of 500 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port-gentil,ga
# ---------------------------------------------------------------------------------------------
# Processing city 149 out of 500 | Bardiyah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bardiyah,ly
# ---------------------------------------------------------------------------------------------
# Processing city 150 out of 500 | Fort Abbas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=fort abbas,pk
# ---------------------------------------------------------------------------------------------
# Processing city 151 out of 500 | Ouadda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ouadda,cf
# ---------------------------------------------------------------------------------------------
# Processing city 152 out of 500 | Sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sumbe,ao
# ---------------------------------------------------------------------------------------------
# Processing city 153 out of 500 | Bouar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bouar,cf
# ---------------------------------------------------------------------------------------------
# Processing city 154 out of 500 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=harper,lr
# ---------------------------------------------------------------------------------------------
# Processing city 155 out of 500 | Ayorou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ayorou,ne
# ---------------------------------------------------------------------------------------------
# Processing city 156 out of 500 | Grand-Lahou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=grand-lahou,ci
# ---------------------------------------------------------------------------------------------
# Processing city 157 out of 500 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hobyo,so
# ---------------------------------------------------------------------------------------------
# Processing city 158 out of 500 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bredasdorp,za
# ---------------------------------------------------------------------------------------------
# Processing city 159 out of 500 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port-gentil,ga
# ---------------------------------------------------------------------------------------------
# Processing city 160 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 161 out of 500 | Atar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=atar,mr
# ---------------------------------------------------------------------------------------------
# Processing city 162 out of 500 | East London
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=east london,za
# ---------------------------------------------------------------------------------------------
# Processing city 163 out of 500 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=nisia floresta,br
# ---------------------------------------------------------------------------------------------
# Processing city 164 out of 500 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao filipe,cv
# ---------------------------------------------------------------------------------------------
# Processing city 165 out of 500 | Pisco
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=pisco,pe
# ---------------------------------------------------------------------------------------------
# Processing city 166 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 167 out of 500 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mar del plata,ar
# ---------------------------------------------------------------------------------------------
# Processing city 168 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 169 out of 500 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=nanortalik,gl
# ---------------------------------------------------------------------------------------------
# Processing city 170 out of 500 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=los llanos de aridane,es
# ---------------------------------------------------------------------------------------------
# Processing city 171 out of 500 | Atuona
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=atuona,pf
# ---------------------------------------------------------------------------------------------
# Processing city 172 out of 500 | Willowmore
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=willowmore,za
# ---------------------------------------------------------------------------------------------
# Processing city 173 out of 500 | Adrar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=adrar,dz
# ---------------------------------------------------------------------------------------------
# Processing city 174 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 175 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 176 out of 500 | Sao Sebastiao
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao sebastiao,br
# ---------------------------------------------------------------------------------------------
# Processing city 177 out of 500 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=coihaique,cl
# ---------------------------------------------------------------------------------------------
# Processing city 178 out of 500 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ribeira grande,pt
# ---------------------------------------------------------------------------------------------
# Processing city 179 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 180 out of 500 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=punta arenas,cl
# ---------------------------------------------------------------------------------------------
# Processing city 181 out of 500 | Soroti
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=soroti,ug
# ---------------------------------------------------------------------------------------------
# Processing city 182 out of 500 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=port-gentil,ga
# ---------------------------------------------------------------------------------------------
# Processing city 183 out of 500 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao filipe,cv
# ---------------------------------------------------------------------------------------------
# Processing city 184 out of 500 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ambovombe,mg
# ---------------------------------------------------------------------------------------------
# Processing city 185 out of 500 | Fort Saint James
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=fort saint james,ca
# ---------------------------------------------------------------------------------------------
# Processing city 186 out of 500 | Gamba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=gamba,ga
# ---------------------------------------------------------------------------------------------
# Processing city 187 out of 500 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=caravelas,br
# ---------------------------------------------------------------------------------------------
# Processing city 188 out of 500 | Prachin Buri
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=prachin buri,th
# ---------------------------------------------------------------------------------------------
# Processing city 189 out of 500 | Mumford
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mumford,gh
# ---------------------------------------------------------------------------------------------
# Processing city 190 out of 500 | Rubiataba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rubiataba,br
# ---------------------------------------------------------------------------------------------
# Processing city 191 out of 500 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=klaksvik,fo
# ---------------------------------------------------------------------------------------------
# Processing city 192 out of 500 | Coquimbo
# ...
# Processing city 438 out of 500 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=takoradi,gh
# ---------------------------------------------------------------------------------------------
# Processing city 439 out of 500 | Zaria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=zaria,ng
# ---------------------------------------------------------------------------------------------
# Processing city 440 out of 500 | Kerouane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kerouane,gn
# ---------------------------------------------------------------------------------------------
# Processing city 441 out of 500 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cape town,za
# ---------------------------------------------------------------------------------------------
# Processing city 442 out of 500 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=harper,lr
# ---------------------------------------------------------------------------------------------
# Processing city 443 out of 500 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=takoradi,gh
# ---------------------------------------------------------------------------------------------
# Processing city 444 out of 500 | Shache
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=shache,cn
# ---------------------------------------------------------------------------------------------
# Processing city 445 out of 500 | Castro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=castro,cl
# ---------------------------------------------------------------------------------------------
# Processing city 446 out of 500 | Chiredzi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=chiredzi,zw
# ---------------------------------------------------------------------------------------------
# Processing city 447 out of 500 | Mardan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=mardan,pk
# ---------------------------------------------------------------------------------------------
# Processing city 448 out of 500 | Iranshahr
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=iranshahr,ir
# ---------------------------------------------------------------------------------------------
# Processing city 449 out of 500 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tessalit,ml
# ---------------------------------------------------------------------------------------------
# Processing city 450 out of 500 | Soyo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=soyo,ao
# ---------------------------------------------------------------------------------------------
# Processing city 451 out of 500 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=saint-augustin,ca
# ---------------------------------------------------------------------------------------------
# Processing city 452 out of 500 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=nanortalik,gl
# ---------------------------------------------------------------------------------------------
# Processing city 453 out of 500 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=santa isabel do rio negro,br
# ---------------------------------------------------------------------------------------------
# Processing city 454 out of 500 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=porto novo,cv
# ---------------------------------------------------------------------------------------------
# Processing city 455 out of 500 | Tuy Hoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=tuy hoa,vn
# ---------------------------------------------------------------------------------------------
# Processing city 456 out of 500 | Garowe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=garowe,so
# ---------------------------------------------------------------------------------------------
# Processing city 457 out of 500 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kalmunai,lk
# ---------------------------------------------------------------------------------------------
# Processing city 458 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 459 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 460 out of 500 | Senanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=senanga,zm
# ---------------------------------------------------------------------------------------------
# Processing city 461 out of 500 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=belmonte,br
# ---------------------------------------------------------------------------------------------
# Processing city 462 out of 500 | Misratah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=misratah,ly
# ---------------------------------------------------------------------------------------------
# Processing city 463 out of 500 | Adrar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=adrar,dz
# ---------------------------------------------------------------------------------------------
# Processing city 464 out of 500 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=santiago del estero,ar
# ---------------------------------------------------------------------------------------------
# Processing city 465 out of 500 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=punta arenas,cl
# ---------------------------------------------------------------------------------------------
# Processing city 466 out of 500 | Marabba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=marabba,sd
# ---------------------------------------------------------------------------------------------
# Processing city 467 out of 500 | Castro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=castro,cl
# ---------------------------------------------------------------------------------------------
# Processing city 468 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 469 out of 500 | Birjand
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=birjand,ir
# ---------------------------------------------------------------------------------------------
# Processing city 470 out of 500 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kasongo-lunda,cd
# ---------------------------------------------------------------------------------------------
# Processing city 471 out of 500 | Dubai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=dubai,ae
# ---------------------------------------------------------------------------------------------
# Processing city 472 out of 500 | Busselton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=busselton,au
# ---------------------------------------------------------------------------------------------
# Processing city 473 out of 500 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=punta arenas,cl
# ---------------------------------------------------------------------------------------------
# Processing city 474 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 475 out of 500 | Dharchula
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=dharchula,in
# ---------------------------------------------------------------------------------------------
# Processing city 476 out of 500 | Rongai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rongai,ke
# ---------------------------------------------------------------------------------------------
# Processing city 477 out of 500 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=jamestown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 478 out of 500 | Kissidougou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kissidougou,gn
# ---------------------------------------------------------------------------------------------
# Processing city 479 out of 500 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=arraial do cabo,br
# ---------------------------------------------------------------------------------------------
# Processing city 480 out of 500 | Khilok
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=khilok,ru
# ---------------------------------------------------------------------------------------------
# Processing city 481 out of 500 | Namibe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=namibe,ao
# ---------------------------------------------------------------------------------------------
# Processing city 482 out of 500 | Keita
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=keita,ne
# ---------------------------------------------------------------------------------------------
# Processing city 483 out of 500 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=luderitz,na
# ---------------------------------------------------------------------------------------------
# Processing city 484 out of 500 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=georgetown,sh
# ---------------------------------------------------------------------------------------------
# Processing city 485 out of 500 | Pisco
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=pisco,pe
# ---------------------------------------------------------------------------------------------
# Processing city 486 out of 500 | Sironko
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sironko,ug
# ---------------------------------------------------------------------------------------------
# Processing city 487 out of 500 | Axim
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=axim,gh
# ---------------------------------------------------------------------------------------------
# Processing city 488 out of 500 | Erdenet
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=erdenet,mn
# ---------------------------------------------------------------------------------------------
# Processing city 489 out of 500 | Saint George
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=saint george,bm
# ---------------------------------------------------------------------------------------------
# Processing city 490 out of 500 | Bonoua
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bonoua,ci
# ---------------------------------------------------------------------------------------------
# Processing city 491 out of 500 | Sao Felix do Xingu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=sao felix do xingu,br
# ---------------------------------------------------------------------------------------------
# Processing city 492 out of 500 | Robertsport
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=robertsport,lr
# ---------------------------------------------------------------------------------------------
# Processing city 493 out of 500 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=grand gaube,mu
# ---------------------------------------------------------------------------------------------
# Processing city 494 out of 500 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=bambous virieux,mu
# ---------------------------------------------------------------------------------------------
# Processing city 495 out of 500 | Yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=yenagoa,ng
# ---------------------------------------------------------------------------------------------
# Processing city 496 out of 500 | Kalabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=kalabo,zm
# ---------------------------------------------------------------------------------------------
# Processing city 497 out of 500 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ushuaia,ar
# ---------------------------------------------------------------------------------------------
# Processing city 498 out of 500 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ponta do sol,cv
# ---------------------------------------------------------------------------------------------
# Processing city 499 out of 500 | Turmalina
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=turmalina,br
# ---------------------------------------------------------------------------------------------
# Processing city 500 out of 500 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=cape town,za
# ---------------------------------------------------------------------------------------------

# %%
weather_data_list = {"City Name": city_data, "City Number": city_code,"Latitude": lat_data, "Temperature": temp_data, 
                     "Humidity": humidity_data, "Cloudiness":cloudiness_data, "Windspeed" : windspeed_data, "URL" : req_url}
weather_data_pd = pd.DataFrame(weather_data_list)
weather_data_pd.to_csv("LatWeatherRelationship.csv", index =False)
weather_data_pd
# Out:
#            City Name  City Number  Cloudiness  Humidity  Latitude  \
# 0             Mopipi          200          92        98    -21.20
# 1            Cayenne          200          75        94      4.94
# 2           Cidreira          200          44        85    -30.17
# 3            Ushuaia          200          40        50    -54.81
# 4              Amapa          200          88        94     -1.83
# 5            Mumford          200          48        95      5.26
# 6    Arraial do Cabo          200          80        94    -22.97
# 7             Torbay          200          20        78     47.66
# 8        New Norfolk          200          40        40    -42.78
# 9             Touros          200           0        98     -5.20
# 10            Albany          200          20        74    -35.02
# 11            Chilca          200          75        62    -13.22
# 12         Kilindoni          200           0       100     -7.91
# 13         Cocobeach          200          75        88      1.01
# 14           Kassala          200           0        67     15.45
# 15         San-Pedro          200          80        84      4.75
# 16            Maceio          200          40        83     -9.67
# 17       Port-Gentil          200          92       100     -0.72
# 18           Fomboni          200          12       100    -12.28
# 19          Coquimbo          200           0        87    -29.95
# 20           Itarema          200          92       100     -2.92
# 21          Monrovia          200          20        87      6.33
# 22     San Cristobal          200          64       100     -1.02
# 23    Ribeira Grande          200          92       100     38.52
# 24            Namibe          200           0       100    -15.19
# 25             Lagoa          200          75       100     37.14
# 26         Grindavik          200          75        93     63.84
# 27              Lebu          200          56        94    -37.62
# 28              Hilo          200          90        88     19.71
# 29           Kangaba          200          64        66     11.94
# ..               ...          ...         ...       ...       ...
# 505         Maragogi          200         100       100     -9.01
# 506        Kisangani          200          64       100      0.52
# 507        Bathsheba          200          20        73     13.22
# 508            Asosa          200           0        62     10.07
# 509          Rikitea          200          24       100    -23.12
# 510          Ushuaia          200          40        50    -54.81
# 511             Hami          200          56        57     42.84
# 512      Port-Gentil          200          92       100     -0.72
# 513            Arona          200          40        67     28.10
# 514           Taltal          200           0       100    -25.41
# 515             Hovd          200          12        64     48.01
# 516            Keita          200           8        61     14.76
# 517            Lubao          200          56        84     -5.39
# 518   Terekli-Mekteb          200          92        97     44.16
# 519          Yenagoa          200          88        93      4.92
# 520            Matam          200           0        65     15.66
# 521   Saint-Philippe          200           0        78    -21.36
# 522         Takoradi          200          80       100      4.89
# 523     Puerto Ayora          200          92       100     -0.74
# 524        Ugoofaaru          200          92        99      5.67
# 525             Uaua          200           0        71     -9.84
# 526             Axim          200          92        99      4.87
# 527        Cape Town          200           0        71    -33.93
# 528             Muli          200          48       100      2.92
# 529          Senanga          200          92        98    -16.10
# 530         Takoradi          200          80       100      4.89
# 531             Axim          200          92        99      4.87
# 532             Soyo          200          92        96     -6.13
# 533            Yendi          200          76        94      9.45
# 534         Buraydah          200           0        87     26.33
#
#      Temperature                                                URL  Windspeed
# 0          65.52  http://api.openweathermap.org/data/2.5/weather...      15.39
# 1          75.20  http://api.openweathermap.org/data/2.5/weather...       5.82
# 2          71.28  http://api.openweathermap.org/data/2.5/weather...       9.80
# 3          55.40  http://api.openweathermap.org/data/2.5/weather...       9.17
# 4          75.24  http://api.openweathermap.org/data/2.5/weather...       2.64
# 5          77.13  http://api.openweathermap.org/data/2.5/weather...       6.67
# 6          76.63  http://api.openweathermap.org/data/2.5/weather...       6.22
# 7          14.00  http://api.openweathermap.org/data/2.5/weather...       9.17
# 8          68.00  http://api.openweathermap.org/data/2.5/weather...       5.82
# 9          75.73  http://api.openweathermap.org/data/2.5/weather...       5.44
# 10         68.44  http://api.openweathermap.org/data/2.5/weather...      11.25
# 11         55.40  http://api.openweathermap.org/data/2.5/weather...       3.36
# 12         81.58  http://api.openweathermap.org/data/2.5/weather...       6.89
# 13         78.80  http://api.openweathermap.org/data/2.5/weather...       3.36
# 14         58.68  http://api.openweathermap.org/data/2.5/weather...       2.75
# 15         77.58  http://api.openweathermap.org/data/2.5/weather...       7.78
# 16         75.20  http://api.openweathermap.org/data/2.5/weather...       6.93
# 17         75.15  http://api.openweathermap.org/data/2.5/weather...       8.12
# 18         82.66  http://api.openweathermap.org/data/2.5/weather...       5.99
# 19         59.00  http://api.openweathermap.org/data/2.5/weather...       6.22
# 20         74.56  http://api.openweathermap.org/data/2.5/weather...       2.42
# 21         74.97  http://api.openweathermap.org/data/2.5/weather...       3.76
# 22         59.94  http://api.openweathermap.org/data/2.5/weather...       1.86
# 23         58.81  http://api.openweathermap.org/data/2.5/weather...      31.50
# 24         75.69  http://api.openweathermap.org/data/2.5/weather...       3.76
# 25         53.60  http://api.openweathermap.org/data/2.5/weather...      11.41
# 26         44.60  http://api.openweathermap.org/data/2.5/weather...      32.21
# 27         60.16  http://api.openweathermap.org/data/2.5/weather...      11.92
# 28         64.20  http://api.openweathermap.org/data/2.5/weather...       3.36
# 29         77.53  http://api.openweathermap.org/data/2.5/weather...       2.75
# ..           ...                                                ...        ...
# 505        75.19  http://api.openweathermap.org/data/2.5/weather...       5.66
# 506        70.02  http://api.openweathermap.org/data/2.5/weather...       3.76
# 507        75.20  http://api.openweathermap.org/data/2.5/weather...      16.11
# 508        57.33  http://api.openweathermap.org/data/2.5/weather...       2.30
# 509        79.20  http://api.openweathermap.org/data/2.5/weather...      10.69
# 510        55.40  http://api.openweathermap.org/data/2.5/weather...       9.17
# 511        39.60  http://api.openweathermap.org/data/2.5/weather...       8.23
# 512        75.15  http://api.openweathermap.org/data/2.5/weather...       8.12
# 513        57.07  http://api.openweathermap.org/data/2.5/weather...      11.41
# 514        52.78  http://api.openweathermap.org/data/2.5/weather...       1.63
# 515        11.83  http://api.openweathermap.org/data/2.5/weather...       0.85
# 516        70.78  http://api.openweathermap.org/data/2.5/weather...       7.00
# 517        72.54  http://api.openweathermap.org/data/2.5/weather...       2.64
# 518        37.80  http://api.openweathermap.org/data/2.5/weather...       4.65
# 519        75.69  http://api.openweathermap.org/data/2.5/weather...       5.77
# 520        65.52  http://api.openweathermap.org/data/2.5/weather...       7.00
# 521        78.91  http://api.openweathermap.org/data/2.5/weather...       8.05
# 522        79.02  http://api.openweathermap.org/data/2.5/weather...       6.22
# 523        73.39  http://api.openweathermap.org/data/2.5/weather...       1.74
# 524        82.84  http://api.openweathermap.org/data/2.5/weather...      15.05
# 525        71.82  http://api.openweathermap.org/data/2.5/weather...       6.33
# 526        80.59  http://api.openweathermap.org/data/2.5/weather...       9.46
# 527        57.20  http://api.openweathermap.org/data/2.5/weather...       9.17
# 528        79.29  http://api.openweathermap.org/data/2.5/weather...       7.23
# 529        64.93  http://api.openweathermap.org/data/2.5/weather...       8.46
# 530        79.02  http://api.openweathermap.org/data/2.5/weather...       6.22
# 531        80.59  http://api.openweathermap.org/data/2.5/weather...       9.46
# 532        76.14  http://api.openweathermap.org/data/2.5/weather...       1.41
# 533        72.90  http://api.openweathermap.org/data/2.5/weather...       4.99
# 534        59.00  http://api.openweathermap.org/data/2.5/weather...       2.24
#
# [535 rows x 8 columns]

# %%
# Build a scatter plot for Temperature (F) vs. Latitude
plt.figure(figsize=(8, 8))
plt.scatter(weather_data_pd["Latitude"], weather_data_pd["Temperature"], marker="o",facecolors="red", edgecolors="black")

# Incorporate the other graph properties
plt.title("Temperature vs Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-100,100)


# Save the figure
plt.savefig("TempvsLat.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for Humidity (%) vs. Latitude
plt.figure(figsize=(8, 8))
plt.scatter(weather_data_pd["Latitude"], weather_data_pd["Humidity"], marker="o",facecolors="red", edgecolors="black")

# Incorporate the other graph properties
plt.title("Humidty vs Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-100,100)


# Save the figure
plt.savefig("HumvsLat.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for Cloudiness (%) vs. Latitude
plt.figure(figsize=(8, 8))
plt.scatter(weather_data_pd["Latitude"], weather_data_pd["Cloudiness"], marker="o",facecolors="red", edgecolors="black")

# Incorporate the other graph properties
plt.title("Cloudiness vs Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-100,100)


# Save the figure
plt.savefig("CloudvsLat.png")


# Show plot
plt.show()

# %%
# Build a scatter plot for Wind Speed (mph) vs. Latitude
plt.figure(figsize=(8, 8))
plt.scatter(weather_data_pd["Latitude"], weather_data_pd["Windspeed"], marker="o",facecolors="red", edgecolors="black")

# Incorporate the other graph properties
plt.title("Wind Speed vs Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-100,100)


# Save the figure
plt.savefig("WSvsLat.png")


# Show plot
plt.show()
